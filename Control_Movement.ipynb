# %% [markdown]
# # sM1_12-12-2023_03: Control, Movement

# %% [markdown]
# This notebook shows how you can analyze data streamed from our NWB data residing in the DANDI archive.

# %%
from dandi.dandiapi import DandiAPIClient
import fsspec
from fsspec.implementations.cached import CachingFileSystem
import h5py
import matplotlib.pyplot as plt
import numpy as np
import pynwb

# %% [markdown]
# The data used in this tutorial were used in this publication: Doherty, et al. "Enhanced beta power emerges from simulated parkinsonian primary motor cortex." npj Parkinson's Disease (2025). (https://doi.org/10.1101/2024.05.23.595566) The data can be found on the DANDI Archive in Dandiset 001444.

# %%
dandiset_id = "001444"
filepath = "sub-001/sub-001_ses-sM1-12-12-2023-03.nwb"
with DandiAPIClient() as client:
    asset = client.get_dandiset(dandiset_id, 'draft').get_asset_by_path(filepath)
    s3_url = asset.get_content_url(follow_redirects=1, strip_query=True)

# %% [markdown]
# Stream the NWB files from DANDI

# %%
# create a virtual http filesystem with local caching
fs = CachingFileSystem(
    fs=fsspec.filesystem("http"),
    cache_storage="nwb-cache",  # local folder for the cache
)

# %%
# open the file using the S3 URL
f = fs.open(s3_url, "rb")
file = h5py.File(f)
io = pynwb.NWBHDF5IO(file=file)
nwbfile = io.read()

# %% [markdown]
# ## Plot the Local Field Potential (LFP)

# %%
# 40 samples per ms
# data window from 2 seconds (2000 ms) to 2.25 sec (2250 ms)
xmin = 2000 * 40
xmax = 2250 * 40
plt.figure(figsize=(15,5))
plt.xlim(xmin, xmax)
plt.ylim(-0.17, 0.05)
plt.title('Control Movement', fontsize= 30)
plt.plot(nwbfile.acquisition.get('Segment 0 LFP 0').data, color='black')
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %% [markdown]
# ## Raster plot of all M1 neurons

# %%
units_df = nwbfile.units.to_dataframe()

excitatory_neurons = ['IT2', 'IT4', 'IT5A', 'IT5B', 'PT5B', 'IT6', 'CT6']
inhibitory_neurons = ['PV2', 'SOM2', 'PV5A', 'SOM5A', 'PV5B', 'SOM5B', 'PV6', 'SOM6']

# %%
for i, unit in enumerate(units_df['_name']):
    pop_unit = unit.split()
    units_df.loc[i, 'pop'] = pop_unit[0]
    units_df.loc[i, 'unit'] = pop_unit[1]
    if units_df.loc[i]['pop'] in excitatory_neurons:
        units_df.loc[i, 'color'] = 'red'
    elif units_df.loc[i]['pop'] in inhibitory_neurons:
        units_df.loc[i, 'color'] = 'black'

units_df['unit'].astype(int, copy=False);

# %%
m1_units_df = units_df[~units_df['color'].isna()]

# %%
plt.figure(figsize=(15,10))
#plt.ylim(0, 10073)
plt.gca().invert_yaxis()
ax = plt.gca()

xmin = 2.000
xmax = 2.250
plt.xlim(xmin, xmax)

ax.tick_params(axis='both', which='major', labelsize=15)
plt.xticks([])
plt.yticks([])

for i, st in enumerate(m1_units_df['spike_times']):
    ax.scatter(st, np.full(len(m1_units_df.iloc[i]['spike_times']), m1_units_df.iloc[i]['unit'], dtype=int), color=m1_units_df.iloc[i]['color'], s=5)

# %% [markdown]
# ## Plot example pyramidal tract (PT5B) neuron membrane potential traces

# %% [markdown]
# Example traces in Fig 2 and 5 are from PT5B 5401, 5501, 5702, 5602, and 6201 2000-2250 ms

# %%
start = 2000*40
stop = 2250*40

# %%
example_traces = ['Segment 0 PT5B 5401 5', 'Segment 0 PT5B 5501 7', 'Segment 0 PT5B 5702 12', 'Segment 0 PT5B 5602 10', 'Segment 0 PT5B 6201 15']

fig = plt.figure(figsize=(8,8))

ax = fig.subplots(5, 1)
for i, vm in enumerate(example_traces):
    vm_data = nwbfile.acquisition.get(vm).data
    ax[i].set_xlim(start, stop)
    ax[i].tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['bottom'].set_visible(False)
    ax[i].spines['left'].set_visible(False)
    ax[i].plot(vm_data, color='brown')

# %% [markdown]
# ## Simplified, interactive representation of the contents of this NWB file

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x5323172448
# Fields:
#   acquisition: {
#     Segment 0 LFP 0 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5201 1 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5202 2 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5301 3 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5302 4 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5401 5 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5402 6 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5501 7 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5502 8 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5601 9 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5602 10 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5701 11 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5702 12 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5801 13 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 5802 14 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 6201 15 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 6202 16 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 6301 17 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 6302 18 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 6501 19 <class 'pynwb.base.TimeSeries'>,
#     Segment 0 PT5B 6502 20 <class 'pynwb.base.TimeSeries'>
#   }
#   experiment_description: Simulated mouse primary motor cortex in control and 6-OHDA induced parkinsonism.
#   experimenter: ['Doherty, Donald']
#   file_create_date: [datetime.datetime(2025, 7, 6, 8, 44, 43, 722970, tzinfo=tzoffset(None, -14400))]
#   identifier: 989ec338-a01b-484d-b445-f3a880aaa935
#   institution: SUNY Downstate Health Sciences University
#   keywords: <StrDataset for HDF5 dataset "keywords": shape (5,), type "|O">
#   lab: NeuroSim Lab
#   related_publications: ['https://doi.org/10.1101/2024.05.23.595566']
#   session_description: control, movement
#   session_id: sM1_12-12-2023_03
#   session_start_time: 2023-12-12 15:29:00-05:00
#   subject: subject pynwb.file.Subject at 0x5323241552
# Fields:
#   age: P16W
#   age__reference: birth
#   description: simulated mouse
#   sex: O
#   species: Mus musculus
#   subject_id: 001
#
#   timestamps_reference_time: 2023-12-12 15:29:00-05:00
#   units: units <class 'pynwb.misc.Units'>
